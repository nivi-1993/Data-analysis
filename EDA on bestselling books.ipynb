# %% [markdown]
# # Exploring and Processing Data

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Import Data

# %%
df = pd.read_csv('..../..../..../bestsellers with categories.csv')
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info() #checking if any NA or null values exist
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %% [markdown]
# ## selection

# %%
df.Name
# Out:
# 0                          10-Day Green Smoothie Cleanse
# 1                                      11/22/63: A Novel
# 2                12 Rules for Life: An Antidote to Chaos
# 3                                 1984 (Signet Classics)
# 4      5,000 Awesome Facts (About Everything!) (Natio...
#                              ...
# 545         Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546    You Are a Badass: How to Stop Doubting Your Gr...
# 547    You Are a Badass: How to Stop Doubting Your Gr...
# 548    You Are a Badass: How to Stop Doubting Your Gr...
# 549    You Are a Badass: How to Stop Doubting Your Gr...
# Name: Name, Length: 550, dtype: object

# %%
df['Name'] #selecting one column
# Out:
# 0                          10-Day Green Smoothie Cleanse
# 1                                      11/22/63: A Novel
# 2                12 Rules for Life: An Antidote to Chaos
# 3                                 1984 (Signet Classics)
# 4      5,000 Awesome Facts (About Everything!) (Natio...
#                              ...
# 545         Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546    You Are a Badass: How to Stop Doubting Your Gr...
# 547    You Are a Badass: How to Stop Doubting Your Gr...
# 548    You Are a Badass: How to Stop Doubting Your Gr...
# 549    You Are a Badass: How to Stop Doubting Your Gr...
# Name: Name, Length: 550, dtype: object

# %%
df[['Name', 'Author']] #selecting multiple columns
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# ..                        ...
# 545               Jeff Kinney
# 546               Jen Sincero
# 547               Jen Sincero
# 548               Jen Sincero
# 549               Jen Sincero
#
# [550 rows x 2 columns]

# %% [markdown]
# ## duplicate df as required

# %%
newdf = df[['Name','Author','Genre']]
newdf.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author        Genre
# 0                  JJ Smith  Non Fiction
# 1              Stephen King      Fiction
# 2        Jordan B. Peterson  Non Fiction
# 3             George Orwell      Fiction
# 4  National Geographic Kids  Non Fiction

# %% [markdown]
# ## Indexing

# %%
df.loc[5:10,] # loc is used for label based indexing. 5 to 10 rows and all columns
# Out:
#                                                  Name               Author  \
# 5       A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6   A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                      A Gentleman in Moscow: A Novel          Amor Towles
# 8       A Higher Loyalty: Truth, Lies, and Leadership          James Comey
# 9                           A Man Called Ove: A Novel      Fredrik Backman
# 10                          A Man Called Ove: A Novel      Fredrik Backman
#
#     User Rating  Reviews  Price  Year        Genre
# 5           4.4    12643     11  2011      Fiction
# 6           4.7    19735     30  2014      Fiction
# 7           4.7    19699     15  2017      Fiction
# 8           4.7     5983      3  2018  Non Fiction
# 9           4.6    23848      8  2016      Fiction
# 10          4.6    23848      8  2017      Fiction

# %%
df.loc[5:10, 'Name':'User Rating'] # specified range of rows and columns
# Out:
#                                                  Name               Author  \
# 5       A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6   A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                      A Gentleman in Moscow: A Novel          Amor Towles
# 8       A Higher Loyalty: Truth, Lies, and Leadership          James Comey
# 9                           A Man Called Ove: A Novel      Fredrik Backman
# 10                          A Man Called Ove: A Novel      Fredrik Backman
#
#     User Rating
# 5           4.4
# 6           4.7
# 7           4.7
# 8           4.7
# 9           4.6
# 10          4.6

# %% [markdown]
# ## summary statistics

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# ## Plots

# %%
df['Genre'].value_counts() #counts unique values
# Out:
# Non Fiction    310
# Fiction        240
# Name: Genre, dtype: int64

# %%
df['Genre'].value_counts(normalize=True) #percentage of the quantities
# Out:
# Non Fiction    0.563636
# Fiction        0.436364
# Name: Genre, dtype: float64

# %%
df['Genre'].value_counts().plot(kind='bar') #visualization

# %% [markdown]
# ### So during 2009-2019 the no. of Non Fiction Books are greater than the Fiction Books in the list of bestselling books.
# ### This implies people love to read NFBs than FBs

# %%
df['Genre'].value_counts().plot(kind='pie')

# %%
df.groupby('Genre')['Price'].sum().plot(kind='pie') #price comparison

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize' ]= (12,7)
df.Author.value_counts().sort_values(ascending=False).head(15).plot(kind='bar', color='green')
plt.title('Top 15 Authors with highest number of Books Published',fontsize=18)
plt.xlabel('Authors',fontsize=15)
plt.ylabel('No. of Books',fontsize=15)
plt.show()

# %%
Authors = df["Author"].value_counts()
Agtfb = Authors[Authors >= 5] 
Agtfb #Author greater than five books
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
# Dr. Seuss                              9
# Gallup                                 9
# Rob Elliott                            8
# Stephenie Meyer                        7
# Bill O'Reilly                          7
# Eric Carle                             7
# Stephen R. Covey                       7
# Dav Pilkey                             7
# Stieg Larsson                          6
# Don Miguel Ruiz                        6
# E L James                              6
# J.K. Rowling                           6
# The College Board                      6
# Sarah Young                            6
# Harper Lee                             6
# Dale Carnegie                          5
# Roger Priddy                           5
# R. J. Palacio                          5
# John Grisham                           5
# Patrick Lencioni                       5
# Giles Andreae                          5
# John Green                             5
# Laura Hillenbrand                      5
# Name: Author, dtype: int64

# %%
df[['Name','Author','User Rating']].nlargest(15, 'User Rating') # 15 Books with highest user ratings
# Out:
#                                                   Name                Author  \
# 40            Brown Bear, Brown Bear, What Do You See?       Bill Martin Jr.
# 41            Brown Bear, Brown Bear, What Do You See?       Bill Martin Jr.
# 81   Dog Man and Cat Kid: From the Creator of Capta...            Dav Pilkey
# 82   Dog Man: A Tale of Two Kitties: From the Creat...            Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...            Dav Pilkey
# 84   Dog Man: Brawl of the Wild: From the Creator o...            Dav Pilkey
# 85   Dog Man: Fetch-22: From the Creator of Captain...            Dav Pilkey
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...            Dav Pilkey
# 87   Dog Man: Lord of the Fleas: From the Creator o...            Dav Pilkey
# 146  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
# 147  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
# 151                           Hamilton: The Revolution    Lin-Manuel Miranda
# 153  Harry Potter and the Chamber of Secrets: The I...          J.K. Rowling
# 155  Harry Potter and the Goblet of Fire: The Illus...         J. K. Rowling
# 156  Harry Potter and the Prisoner of Azkaban: The ...          J.K. Rowling
#
#      User Rating
# 40           4.9
# 41           4.9
# 81           4.9
# 82           4.9
# 83           4.9
# 84           4.9
# 85           4.9
# 86           4.9
# 87           4.9
# 146          4.9
# 147          4.9
# 151          4.9
# 153          4.9
# 155          4.9
# 156          4.9

# %%
df[['Name','Author','User Rating','Genre']].sort_values(by=['User Rating'],ascending=False) #Books according to user rating
# Out:
#                                                   Name         Author  \
# 431                                 The Magnolia Story    Chip Gaines
# 87   Dog Man: Lord of the Fleas: From the Creator o...     Dav Pilkey
# 85   Dog Man: Fetch-22: From the Creator of Captain...     Dav Pilkey
# 84   Dog Man: Brawl of the Wild: From the Creator o...     Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...     Dav Pilkey
# ..                                                 ...            ...
# 22                                           Allegiant  Veronica Roth
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 132                         Go Set a Watchman: A Novel     Harper Lee
# 353                                 The Casual Vacancy   J.K. Rowling
#
#      User Rating        Genre
# 431          4.9  Non Fiction
# 87           4.9      Fiction
# 85           4.9      Fiction
# 84           4.9      Fiction
# 83           4.9      Fiction
# ..           ...          ...
# 22           3.9      Fiction
# 107          3.8      Fiction
# 106          3.8      Fiction
# 132          3.6      Fiction
# 353          3.3      Fiction
#
# [550 rows x 4 columns]

# %%
plt.rcParams['figure.figsize'] = (10,5)
df[['Name','User Rating']].nlargest(15,'User Rating').plot.bar(color='orange')
plt.title('15 Books with highest User Rating',fontsize=18)
plt.xlabel('Name of the Books',fontsize=15)
plt.ylabel('User Rating',fontsize=15)
plt.show()

# %%
df[['Author','Reviews']].nlargest(10, 'Reviews') # Top 10 Authors with highest reviews
# Out:
#              Author  Reviews
# 534     Delia Owens    87841
# 382   Paula Hawkins    79446
# 383   Paula Hawkins    79446
# 32   Michelle Obama    61133
# 33   Michelle Obama    61133
# 135   Gillian Flynn    57271
# 136   Gillian Flynn    57271
# 137   Gillian Flynn    57271
# 365      John Green    50482
# 366      John Green    50482

# %%
plt.rcParams['figure.figsize'] = (10,5)
df[['Name','User Rating']].nlargest(15,'User Rating').plot.bar(color='orange')
plt.title('15 Books with highest User Rating',fontsize=18)
plt.xlabel('Name of the Books',fontsize=15)
plt.ylabel('User Rating',fontsize=15)
plt.show()

# %%
df[['Name','Author','Reviews','Genre']].sort_values(by=['Reviews'],ascending=False) # Books with highest to lowest reviews
# Out:
#                                                   Name             Author  \
# 534                            Where the Crawdads Sing        Delia Owens
# 382                              The Girl on the Train      Paula Hawkins
# 383                              The Girl on the Train      Paula Hawkins
# 32                                            Becoming     Michelle Obama
# 33                                            Becoming     Michelle Obama
# ..                                                 ...                ...
# 359  The Daily Show with Jon Stewart Presents Earth...        Jon Stewart
# 512                             True Compass: A Memoir  Edward M. Kennedy
# 121                    George Washington's Sacred Fire  Peter A. Lillback
# 300  Soul Healing Miracles: Ancient and New Sacred ...       Zhi Gang Sha
# 78   Divine Soul Mind Body Healing and Transmission...       Zhi Gang Sha
#
#      Reviews        Genre
# 534    87841      Fiction
# 382    79446      Fiction
# 383    79446      Fiction
# 32     61133  Non Fiction
# 33     61133  Non Fiction
# ..       ...          ...
# 359      440  Non Fiction
# 512      438  Non Fiction
# 121      408  Non Fiction
# 300      220  Non Fiction
# 78        37  Non Fiction
#
# [550 rows x 4 columns]

# %%
df[['Name','Author','User Rating','Reviews']].nlargest(15,'Reviews') # Books with highest reviews
# Out:
#                                                   Name          Author  \
# 534                            Where the Crawdads Sing     Delia Owens
# 382                              The Girl on the Train   Paula Hawkins
# 383                              The Girl on the Train   Paula Hawkins
# 32                                            Becoming  Michelle Obama
# 33                                            Becoming  Michelle Obama
# 135                                          Gone Girl   Gillian Flynn
# 136                                          Gone Girl   Gillian Flynn
# 137                                          Gone Girl   Gillian Flynn
# 365                             The Fault in Our Stars      John Green
# 366                             The Fault in Our Stars      John Green
# 367                             The Fault in Our Stars      John Green
# 368                             The Fault in Our Stars      John Green
# 437                           The Nightingale: A Novel  Kristin Hannah
# 438                           The Nightingale: A Novel  Kristin Hannah
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...       E L James
#
#      User Rating  Reviews
# 534          4.8    87841
# 382          4.1    79446
# 383          4.1    79446
# 32           4.8    61133
# 33           4.8    61133
# 135          4.0    57271
# 136          4.0    57271
# 137          4.0    57271
# 365          4.7    50482
# 366          4.7    50482
# 367          4.7    50482
# 368          4.7    50482
# 437          4.8    49288
# 438          4.8    49288
# 106          3.8    47265

# %%
plt.rcParams['figure.figsize'] = (10,5)
df[['Name','Reviews']].nlargest(15,'Reviews').plot.bar(color='blue')
plt.title('Top 15 Books with highest number of Reviews',fontsize=18)
plt.xlabel('Name of the Books',fontsize=15)
plt.ylabel('No.of Reviews',fontsize=15)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10,5)
df[df['Genre']=='Fiction'].nlargest(15,'Reviews').plot.bar(x='Name', y='Reviews',color='magenta')
plt.title('Top 15 Fiction Books with highest number of Reviews',fontsize=18)
plt.xlabel('Name of the Books',fontsize=15)
plt.ylabel('No.of Reviews',fontsize=15)
plt.show()

# %%
Top_Fict = df[(df['Genre']=="Fiction")]  
Top_Fict.head(15)
fict_df = Top_Fict.sort_values(by=['Reviews'], ascending=False)
fict_df.head(15)
# Out:
#                                                   Name          Author  \
# 534                            Where the Crawdads Sing     Delia Owens
# 382                              The Girl on the Train   Paula Hawkins
# 383                              The Girl on the Train   Paula Hawkins
# 135                                          Gone Girl   Gillian Flynn
# 136                                          Gone Girl   Gillian Flynn
# 137                                          Gone Girl   Gillian Flynn
# 365                             The Fault in Our Stars      John Green
# 366                             The Fault in Our Stars      John Green
# 368                             The Fault in Our Stars      John Green
# 367                             The Fault in Our Stars      John Green
# 437                           The Nightingale: A Novel  Kristin Hannah
# 438                           The Nightingale: A Novel  Kristin Hannah
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...       E L James
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...       E L James
# 433                                        The Martian       Andy Weir
#
#      User Rating  Reviews  Price  Year    Genre
# 534          4.8    87841     15  2019  Fiction
# 382          4.1    79446     18  2015  Fiction
# 383          4.1    79446      7  2016  Fiction
# 135          4.0    57271     10  2012  Fiction
# 136          4.0    57271     10  2013  Fiction
# 137          4.0    57271      9  2014  Fiction
# 365          4.7    50482     13  2012  Fiction
# 366          4.7    50482     13  2013  Fiction
# 368          4.7    50482     13  2014  Fiction
# 367          4.7    50482      7  2014  Fiction
# 437          4.8    49288     11  2015  Fiction
# 438          4.8    49288     11  2016  Fiction
# 106          3.8    47265     14  2012  Fiction
# 107          3.8    47265     14  2013  Fiction
# 433          4.7    39459      9  2015  Fiction

# %%
plt.rcParams['figure.figsize'] = (10,5)
df[df['Genre']=='Non Fiction'].nlargest(15,'Reviews').plot.bar(x='Name', y='Reviews',color='purple')
plt.title('Top 15 Non Fiction Books with highest number of Reviews',fontsize=18)
plt.xlabel('Name of the Books',fontsize=15)
plt.ylabel('No.of Reviews',fontsize=15)
plt.show()

# %%
Top_NonFict = df[(df['Genre']=="Non Fiction")]  
Top_NonFict.head(15)
Nonfict_df = Top_NonFict.sort_values(by=['Reviews'], ascending=False)
Nonfict_df.head(15)
# Out:
#                                                   Name             Author  \
# 33                                            Becoming     Michelle Obama
# 32                                            Becoming     Michelle Obama
# 519  Unbroken: A World War II Story of Survival, Re...  Laura Hillenbrand
# 518  Unbroken: A World War II Story of Survival, Re...  Laura Hillenbrand
# 517  Unbroken: A World War II Story of Survival, Re...  Laura Hillenbrand
# 516  Unbroken: A World War II Story of Survival, Re...  Laura Hillenbrand
# 515  Unbroken: A World War II Story of Survival, Re...  Laura Hillenbrand
# 98                                  Educated: A Memoir      Tara Westover
# 97                                  Educated: A Memoir      Tara Westover
# 466  The Subtle Art of Not Giving a F*ck: A Counter...        Mark Manson
# 465  The Subtle Art of Not Giving a F*ck: A Counter...        Mark Manson
# 464  The Subtle Art of Not Giving a F*ck: A Counter...        Mark Manson
# 327  The 5 Love Languages: The Secret to Love that ...       Gary Chapman
# 326  The 5 Love Languages: The Secret to Love that ...       Gary Chapman
# 328  The 5 Love Languages: The Secret to Love that ...       Gary Chapman
#
#      User Rating  Reviews  Price  Year        Genre
# 33           4.8    61133     11  2019  Non Fiction
# 32           4.8    61133     11  2018  Non Fiction
# 519          4.8    29673     16  2014  Non Fiction
# 518          4.8    29673     13  2014  Non Fiction
# 517          4.8    29673     16  2012  Non Fiction
# 516          4.8    29673     16  2011  Non Fiction
# 515          4.8    29673     16  2010  Non Fiction
# 98           4.7    28729     15  2019  Non Fiction
# 97           4.7    28729     15  2018  Non Fiction
# 466          4.6    26490     15  2019  Non Fiction
# 465          4.6    26490     15  2018  Non Fiction
# 464          4.6    26490     15  2017  Non Fiction
# 327          4.8    25554      8  2017  Non Fiction
# 326          4.8    25554      8  2016  Non Fiction
# 328          4.8    25554      8  2018  Non Fiction

# %%
plt.rcParams['figure.figsize'] = (10,5)
df[['Name', 'Price']].nlargest(15,'Price').plot.bar(x='Name', y='Price',color='red')
plt.title('Top 15 Books with highest price',fontsize=18)
plt.xlabel('Name',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %%
df[['Name','Author','Price','Genre']].sort_values(by=['Price'],ascending=False) # Books with highest to lowest price
# Out:
#                                                   Name  \
# 69   Diagnostic and Statistical Manual of Mental Di...
# 70   Diagnostic and Statistical Manual of Mental Di...
# 473                       The Twilight Saga Collection
# 151                           Hamilton: The Revolution
# 346  The Book of Basketball: The NBA According to T...
# ..                                                 ...
# 116                        Frozen (Little Golden Book)
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8
# 505                              To Kill a Mockingbird
# 506                              To Kill a Mockingbird
# 358              The Constitution of the United States
#
#                                Author  Price        Genre
# 69   American Psychiatric Association    105  Non Fiction
# 70   American Psychiatric Association    105  Non Fiction
# 473                   Stephenie Meyer     82      Fiction
# 151                Lin-Manuel Miranda     54  Non Fiction
# 346                      Bill Simmons     53  Non Fiction
# ..                                ...    ...          ...
# 116                         RH Disney      0      Fiction
# 71                        Jeff Kinney      0      Fiction
# 505                        Harper Lee      0      Fiction
# 506                        Harper Lee      0      Fiction
# 358  Delegates of the Constitutional
#       0  Non Fiction
#
# [550 rows x 4 columns]

# %%
df[df['Price'] == 105] #Books with highest price
# Out:
#                                                  Name  \
# 69  Diagnostic and Statistical Manual of Mental Di...
# 70  Diagnostic and Statistical Manual of Mental Di...
#
#                               Author  User Rating  Reviews  Price  Year  \
# 69  American Psychiatric Association          4.5     6679    105  2013
# 70  American Psychiatric Association          4.5     6679    105  2014
#
#           Genre
# 69  Non Fiction
# 70  Non Fiction

# %%
df[df['Price'] == 0] # Books with no cost
# Out:
#                                                   Name  \
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8
# 116                        Frozen (Little Golden Book)
# 193                               JOURNEY TO THE ICE P
# 219                                  Little Blue Truck
# 358              The Constitution of the United States
# 381                                        The Getaway
# 461  The Short Second Life of Bree Tanner: An Eclip...
# 505                              To Kill a Mockingbird
# 506                              To Kill a Mockingbird
# 507                              To Kill a Mockingbird
# 508                              To Kill a Mockingbird
#
#                                Author  User Rating  Reviews  Price  Year  \
# 42                        Jeff Kinney          4.8     4505      0  2011
# 71                        Jeff Kinney          4.8     6812      0  2013
# 116                         RH Disney          4.7     3642      0  2014
# 193                         RH Disney          4.6      978      0  2014
# 219                    Alice Schertle          4.9     1884      0  2014
# 358  Delegates of the Constitutional
#           4.8     2774      0  2016
# 381                       Jeff Kinney          4.8     5836      0  2017
# 461                   Stephenie Meyer          4.6     2122      0  2010
# 505                        Harper Lee          4.8    26234      0  2013
# 506                        Harper Lee          4.8    26234      0  2014
# 507                        Harper Lee          4.8    26234      0  2015
# 508                        Harper Lee          4.8    26234      0  2016
#
#            Genre
# 42       Fiction
# 71       Fiction
# 116      Fiction
# 193      Fiction
# 219      Fiction
# 358  Non Fiction
# 381      Fiction
# 461      Fiction
# 505      Fiction
# 506      Fiction
# 507      Fiction
# 508      Fiction

# %% [markdown]
# #### From the above analysis, it can be observed that 'The Constitution of the US' is the only Non Fiction book available for free of cost.

# %%
df[['Name','Author','Year','Genre']].sort_values(by=['Year'],ascending=False) #Books sorting based on year
# Out:
#                                                   Name                 Author  \
# 549  You Are a Badass: How to Stop Doubting Your Gr...            Jen Sincero
# 294  School Zone - Big Preschool Workbook - Ages 4 ...            School Zone
# 489                   The Wonderful Things You Will Be  Emily Winfield Martin
# 263    P is for Potty! (Sesame Street) (Lift-the-Flap)        Naomi Kleinberg
# 130  Girl, Wash Your Face: Stop Believing the Lies ...          Rachel Hollis
# ..                                                 ...                    ...
# 418  The Last Olympian (Percy Jackson and the Olymp...           Rick Riordan
# 38           Breaking Dawn (The Twilight Saga, Book 4)        Stephenie Meyer
# 92   Eat This, Not That! Thousands of Simple Food S...        David Zinczenko
# 139  Good to Great: Why Some Companies Make the Lea...            Jim Collins
# 299                                  Sookie Stackhouse       Charlaine Harris
#
#      Year        Genre
# 549  2019  Non Fiction
# 294  2019  Non Fiction
# 489  2019      Fiction
# 263  2019  Non Fiction
# 130  2019  Non Fiction
# ..    ...          ...
# 418  2009      Fiction
# 38   2009      Fiction
# 92   2009  Non Fiction
# 139  2009  Non Fiction
# 299  2009      Fiction
#
# [550 rows x 4 columns]

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.countplot(x='Year', data=df, hue='Genre')
plt.title('Number of books over Year by Genre')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Year', y='Price', data=df, hue='Genre')
plt.title('Price over Year by Genre')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Year', y='Reviews', data=df, hue='Genre')
plt.title('Reviews over Year by Genre')
plt.show()

# %%
plt.figure(figsize=(10,3))
sns.barplot(x='Year', y='User Rating', data=df, hue='Genre')
plt.title('User Rating over Year by Genre')
plt.show()

# %%
sns.heatmap(df[['User Rating', 'Reviews', 'Price', 'Year']].corr(),vmin=-1,vmax=1,annot=True)
